# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav-Codes-Git/ZEPTo/blob/main/Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Zepto Dataset Analysis
# ##### **Contribution**    - Individual
# ##### **Team Member  -** **Pranav Deol**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# This project performs Exploratory Data Analysis (EDA) on the Zepto Inventory Dataset to understand product inventory, pricing, discounts, and stock availability. The dataset contains information such as product category, MRP, discounted selling price, discount percentage, available quantity, product weight, and stock status. The objective is to identify patterns that can help improve pricing strategies, inventory management, and business decisions.
#
# The analysis began with understanding and cleaning the dataset by checking data types, missing values, and duplicate records. The dataset was found to be clean with no missing values and only a few duplicate entries, which were removed.
#
# Various visualizations were created using the UBM (Univariate, Bivariate, and Multivariate) approach. These charts helped analyze product distribution, pricing patterns, discounts, stock availability, and relationships between different variables. The correlation heatmap and pair plot showed that MRP and discounted selling price have a strong positive relationship, while discount percentage negatively affects the final selling price.
#
# The analysis highlights the importance of maintaining product availability, applying targeted discounts, and optimizing pricing strategies. It also emphasizes the value of using data analytics for better inventory management and business planning.
#
# Overall, this project demonstrates how Exploratory Data Analysis can convert raw inventory data into meaningful insights, enabling better decision-making, improved customer satisfaction, efficient inventory management, and sustainable business growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# https://github.com/Pranav-Codes-Git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# To perform exploratory data analysis on Zepto inventory dataset to understand pricing trends, discounts, and product distribution

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To gain insights into product pricing, discounts, and inventory distribution to support better business decisions and improve inventory management.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path='/content/drive/MyDrive/zepto_v1.xlsx'
df=pd.read_excel(path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#               Category              name   mrp  discountPercent  \
# 0  Fruits & Vegetables             Onion  2500               16
# 1  Fruits & Vegetables     Tomato Hybrid  4200               16
# 2  Fruits & Vegetables    Tender Coconut  5100               15
# 3  Fruits & Vegetables  Coriander Leaves  2000               15
# 4  Fruits & Vegetables    Ladies Finger   1400               14
# 5  Fruits & Vegetables            Potato  3500               17
# 6  Fruits & Vegetables             Lemon  7500               16
# 7  Fruits & Vegetables       Watermelon   5800               15
# 8  Fruits & Vegetables   Capsicum Green   2300               17
# 9  Fruits & Vegetables     Chilli Green   1900               15
#
#    availableQuantity  discountedSellingPrice  weightInGms  outOfStock  \
# 0                  3                    2100         1000       False
# 1                  3                    3500         1000       False
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 3732
# Columns : 9

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                3732 non-null   object
#  1   name                    3732 non-null   object
#  2   mrp                     3732 non-null   int64
#  3   discountPercent         3732 non-null   int64
#  4   availableQuantity       3732 non-null   int64
#  5   discountedSellingPrice  3732 non-null   int64
#  6   weightInGms             3732 non-null   int64
#  7   outOfStock              3732 non-null   bool
#  8   quantity                3732 non-null   int64
# dtypes: bool(1), int64(6), object(2)
# memory usage: 237.0+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()  #Can be removed during data cleaning
# Out:
# np.int64(2)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Category                  0
# name                      0
# mrp                       0
# discountPercent           0
# availableQuantity         0
# discountedSellingPrice    0
# weightInGms               0
# outOfStock                0
# quantity                  0
# dtype: int64

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# > No missing/null values but contain 2 duplicated values which can be removed during data cleaning

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Category', 'name', 'mrp', 'discountPercent', 'availableQuantity',
#        'discountedSellingPrice', 'weightInGms', 'outOfStock', 'quantity'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  mrp  discountPercent  availableQuantity  \
# count    3732.000000      3732.000000        3732.000000
# mean    15680.117899         7.617095           4.008574
# std     16088.807618         9.211733           2.203511
# min         0.000000         0.000000           0.000000
# 25%      6000.000000         0.000000           2.000000
# 50%     11000.000000         6.000000           5.000000
# 75%     20000.000000        10.000000           6.000000
# max    260000.000000        51.000000           6.000000
#
#        discountedSellingPrice   weightInGms     quantity
# count             3732.000000   3732.000000  3732.000000
# mean             14192.834941    387.843783   213.270900
# std              13850.726265    678.096509   194.730976
# min                  0.000000      0.000000     0.000000
# 25%               5500.000000    100.000000    50.000000
# 50%              10400.000000    225.000000   186.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable**               | **Description**                                                      |
# | -------------------------- | -------------------------------------------------------------------- |
# | **Category**               | Category to which the product belongs (e.g., Fruits, Snacks, Dairy). |
# | **name**                   | Name of the product.                                                 |
# | **mrp**                    | Maximum Retail Price (original price before discount).               |
# | **discountPercent**        | Percentage discount offered on the product.                          |
# | **availableQuantity**      | Quantity of the product currently available in stock.                |
# | **discountedSellingPrice** | Final selling price after applying the discount.                     |
# | **weightInGms**            | Weight of the product in grams.                                      |
# | **outOfStock**             | Indicates whether the product is out of stock       |
# | **quantity**               | Pack size or quantity of the product (e.g., 1 Pack, 500 ml, 2 kg).   |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns:
    print(i,":",df[i].nunique())
# Out:
# Category : 14
# name : 1681
# mrp : 266
# discountPercent : 42
# availableQuantity : 7
# discountedSellingPrice : 350
# weightInGms : 158
# outOfStock : 2
# quantity : 143

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df_2=df.copy()
df_2 = df_2.drop_duplicates()

# %%
df_2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Category', 'name', 'mrp', 'discountPercent', 'availableQuantity',
#        'discountedSellingPrice', 'weightInGms', 'outOfStock', 'quantity'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  mrp  discountPercent  availableQuantity  \
# count    3732.000000      3732.000000        3732.000000
# mean    15680.117899         7.617095           4.008574
# std     16088.807618         9.211733           2.203511
# min         0.000000         0.000000           0.000000
# 25%      6000.000000         0.000000           2.000000
# 50%     11000.000000         6.000000           5.000000
# 75%     20000.000000        10.000000           6.000000
# max    260000.000000        51.000000           6.000000
#
#        discountedSellingPrice   weightInGms     quantity
# count             3732.000000   3732.000000  3732.000000
# mean             14192.834941    387.843783   213.270900
# std              13850.726265    678.096509   194.730976
# min                  0.000000      0.000000     0.000000
# 25%               5500.000000    100.000000    50.000000
# 50%              10400.000000    225.000000   186.000000
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Removal of 2 duplicated columns which were present in initial analysis.

# %% [markdown]
# The overall summary of data using the columns and describe method.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 : Distribution of Products Across Categories

# %%
# Chart - 1 visualization code
plt.figure(figsize=(9,6))
c=['red','blue','teal','grey','orange','black','brown','cyan','indigo']
df_2['Category'].value_counts().plot(kind='bar',color=c)
plt.title('Number of Products in Each Category')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *A bar chart is the best choice for comparing the number of products across different categories. It clearly highlights categories with the highest and lowest product counts.*

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *The inventory is not evenly distributed across categories.*

# %% [markdown]
# *Categories like Cooking Essentials and Munchies have the highest inventory while meat,fish and eggs have lowest inventory.*

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# Categories with a larger number of products provide customers with more choices, increasing customer satisfaction and sales opportunities.
#
# **Negative Impact**
#
# Categories not popular among the masses may indicate low inventory.

# %% [markdown]
# #### Chart - 2 : Distribution of Product MRP (Histogram)

# %%
# Chart - 2 visualization code

# %%
plt.figure(figsize=(10,6))
plt.hist(df_2['mrp'], bins=30, edgecolor='black',color='cyan')

plt.title('Distribution of Product MRP')
plt.xlabel('MRP (₹)')
plt.ylabel('Number of Products')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is suitable for understanding the distribution of a numerical variable. It helps identify the concentration of product prices, skewness, and possible outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *Most products are concentrated in Lower Mrp range*
#
# *Products having higher prices have comparatively less inventory*

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **INSIGHT**
#
# Indian Consumers are extremely price conscious which points to the fact that price is often the primary measure deciding the availablity or inventory of any specific product.
#
# **POSITIVE IMPACT**
#
# Gives a clear idea to online marketplaces like Zepto to increase the inventory of the products with comparatively lower cost and be more conscious of the number of products in higher price ranges.

# %% [markdown]
# #### Chart - 3 : Distribution of Discount Percentage (Box Plot)

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8,5))
plt.boxplot(df_2['discountPercent'], vert=False)

plt.title('Box Plot of Discount Percentage')
plt.xlabel('Discount Percentage')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *A box plot is useful for summarizing the Median,Quartiles and Extreme values together in a single visualization.*

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most products fall within a common discount Percentage.
#
# Few products have higher discount percentages ranging from 40-50% appearing as outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **POSITIVE IMPACT**
#
# Products having higher discount percentages can offer attract several new customers and maintain the retention rate of already existing customers.
#
# **NEGATIVE IMPACT**
#
# Excessive high discounts may often have a negative impact on growth and profit margin if applied without proper planning.
#
# **JUSTIFICATION**
#
# Carefully analyzing and proper planning of discount distribution can maintain a balance between promotional strategy and profitability.

# %% [markdown]
# #### Chart - 4 : Stock Availability (Out of Stock vs In Stock)

# %%
# Chart - 4 visualization code
plt.figure(figsize=(6,6))
df_2['outOfStock'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Stock Availability of Products')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *A pie chart is suitable because the variable has only two categories (In Stock and Out of Stock). It clearly shows the proportion of each category.*

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *Majority of Products are available while only a few items are out of stock*

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# High product availability improves customer satisfaction and enhances the shopping experience.
#
# **Negative Impact**
#
# Out-of-Stock products can often create customer dissatisfaction and may result in them moving to other competing online marketplaces.

# %% [markdown]
# #### Chart - 5 : Top 10 Cheapest Products (Based on MRP)

# %%
# Chart - 5 visualization code

# %%
top10_cheapest = df_2.nsmallest(10, 'discountedSellingPrice')
plt.figure(figsize=(9,6))
plt.bar(top10_cheapest['name'], top10_cheapest['discountedSellingPrice'],color=c)

plt.title('Top 10 Cheapest Products')
plt.xlabel('Product Name')
plt.ylabel('Selling Price (₹)')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is suitable for comparing the prices of the cheapest products. It clearly highlights the lowest-priced items available on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the cherry blossom polish was given as a free product in addition to some other product which the user was purchasing
#
# Ching's brand focuses on minimizing the cost of its goods thus increasing availability for many customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart -  : Distribution of Product Weights

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,6))

plt.hist(df_2['weightInGms'], bins=30, edgecolor='black',color='cyan')

plt.title('Distribution of Product Weight')
plt.xlabel('Weight (grams)')
plt.ylabel('Number of Products')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is appropriate for analyzing the distribution of product weights. It helps identify the most common weight ranges and whether the data is skewed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most products are concentrated in the lower weight range.
#
# The Distribution shows that Zepto primarily stores products under low-medium category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# Maintaining a large variety of lightweight products can improve storage efficiency, simplify deliveries, and meet the demand for everyday grocery items.
#
# **Negative Impact**
#
# Less number of heavy products may prevent the corporations or business looking for bulk orders.

# %% [markdown]
# #### Chart - 7 : Top 10 Highest Discounted Products

# %%
# Chart - 7 visualization code

# %%
top_discount = df_2.nlargest(10, 'discountPercent')
plt.figure(figsize=(9,5))
plt.bar(top_discount['name'], top_discount['discountPercent'],color=c)

plt.title('Top 10 Products with Highest Discount')
plt.xlabel('Product Name')
plt.ylabel('Discount Percentage (%)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The comparison for the highest discounted products is actually a lot easier in a linear representation with bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Companies like Dukes,Chef's Basket and Ceres Foods are observed giving the highest discounts on online marketplace Zepto

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
# High Discounted products often encourage consumers to buy and use those particular products. It also helps in clearing out inventory
#
# **Negative Impact**
# Too much discount without proper planning can mess up cost economy for that product, decreasing profit margin.

# %% [markdown]
# #### Chart - 8 : Category wise average selling price

# %%
# Chart - 8 visualization code
avg_price = df_2.groupby('Category')['discountedSellingPrice'].mean().sort_values(ascending=False)
plt.figure(figsize=(9,6))
avg_price.plot(kind='bar',color=c)

plt.title('Average Selling Price by Category')
plt.xlabel('Category')
plt.ylabel('Average Selling Price (₹)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For comparing the average selling price, a straight linear bar graph is actually very helpful because it clearly highlights the average selling price as shown above.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The daily use-case essentials and Personal care items(like moisturizer,conditioner) had the highest average selling price
#
# Biscuits and Fruits and vegetables had the lowest average selling price

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**:-
#
# Categories having higher average selling price can generate greater revenue per transaction.
#
# **Negative Impact**:-
#
# If the average selling price is too high, the consumers may shift to other competing online marketplaces

# %% [markdown]
# #### Chart - 9 : Average Discount Percentage by Category

# %%
# Chart - 9 visualization code
avg_discount = df_2.groupby('Category')['discountPercent'].mean().sort_values(ascending=False)
plt.figure(figsize=(9,5))
avg_discount.plot(kind='bar',color=c)

plt.title('Average Discount Percentage by Category')
plt.xlabel('Category')
plt.ylabel('Average Discount (%)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Just like the average selling price , the average discount perecentage per category can also be better represented by  Bar Graph

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Daily essential foods like Fruits,Vegetables,meat and eggs saw more average discount percentage
#
# Personal Care items and Home and cleaning essentials had low average discount percentage
#
# We can directly see that Higher discount percentage of daily eseential foods resulted in their lower average selling price and vice-versa for personal care producta.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# Giving High discount percentages can boost customer acquisition and clear out the inventory.
#
# **Negative Impact**
#
# Often high Discount percentages result in low profit margins harming scalability for that product.

# %% [markdown]
# #### Chart - 10 : MRP V/s Discounted Selling Price

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,6))
plt.scatter(df_2['mrp'],
            df_2['discountedSellingPrice'],
            color='blue')

plt.title('MRP vs Discounted Selling Price')
plt.xlabel('MRP (₹)')
plt.ylabel('Discounted Selling Price (₹)')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is the most suitable chart for comparing two numerical variables. It helps identify the relationship between MRP and discounted selling price and reveals pricing patterns or outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a strong positive relationship between MRP and discounted selling price
#
# A few products deviate from the overall trend, indicating unusually high discounts or unique pricing strategies

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# Understanding the relationship between MRP and selling price helps evaluate pricing consistency and supports effective pricing decisions.
#
# **Negative Impact**
#
# Products that significantly deviate from the pricing trend may indicate excessive discounts or inconsistent pricing, potentially reducing profitability.

# %% [markdown]
# #### Chart - 11 : Out-of-Stock Products by Category

# %%
# Chart - 11 visualization code

out_stock = df_2[df_2['outOfStock'] == True]

category_out = out_stock['Category'].value_counts().head(8)

plt.figure(figsize=(10,10))

plt.pie(category_out,
        labels=category_out.index,
        autopct='%1.1f%%',
        startangle=90)

plt.title('Out-of-Stock Products by Category')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart provides a good visual representation in the case of multiple categories and hence can be used for showing the respective perecentages of each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Cooking Essentials and Munchies have the highest out-of-stock percentages.
#
# Fruits,Vegetables and Diary products have lowest out-of-stock percentages.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**:-
#
# By identifying the categories with the highest percentage of out-of-stock products, Zepto can prioritize restocking, improve inventory planning, and ensure that high-demand products remain available
#
# **Negative Impact**:-
#
# Categories with a large share of out-of-stock products may lead to customer dissatisfaction, abandoned purchases, and customers switching to competitors

# %% [markdown]
# #### Chart - 12 : Products Above and Below Average Selling Price

# %%
# Chart - 12 visualization code
avg_price = df_2['discountedSellingPrice'].mean()

price_group = df_2['discountedSellingPrice'].apply(
    lambda x: 'Above Average Price' if x > avg_price else 'Below Average Price'
)
price_group.value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8,8),
    startangle=90
)
plt.title('Products Above and Below Average Selling Price')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart gives a visual representation of the percentage of products above and below average price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 63.8% of Products are below Average Price
#
# 36.2% of Products are above average Selling price

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# Majority of products being lower than average selling price make Zepto a notable option for people ordering stuff online.

# %% [markdown]
# #### Chart - 13 : Average Selling Price by Category and Stock Status

# %%
# Chart - 13 visualization code
plt.figure(figsize=(14,7))
sns.barplot(
    data=df_2,
    x='Category',
    y='discountedSellingPrice',
    hue='outOfStock',
    errorbar=None
)

plt.title('Average Selling Price by Category and Stock Status')
plt.xlabel('Category')
plt.ylabel('Average Selling Price (₹)')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart allows comparison of the average selling price across categories while simultaneously showing the stock status (In Stock vs Out of Stock). It combines three variables into one meaningful visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some high-priced categories have more out-of-stock products, suggesting strong customer demand

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact**
#
# This analysis helps Zepto identify premium products that require better inventory planning, ensuring high-value products remain available for customers.
#
# **Negative Impact**
#
# If expensive products are frequently out of stock, Zepto may lose high-value sales and customer trust, reducing overall revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(8,6))
sns.heatmap(
    df_2.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title('Correlation Heatmap of Numerical Variables')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used to visualize the relationship between numerical variables. It quickly identifies strong positive, negative, or weak correlations, helping understand how different variables influence one another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# MRP and Discounted Selling Price show a strong positive correlation, indicating that products with higher MRPs generally have higher selling prices after discounts.
#
# Discount Percentage has a negative correlation with Discounted Selling Price, meaning larger discounts usually reduce the final selling price.
#
# Available Quantity and Weight have weak correlations with other variables, suggesting they do not significantly influence product pricing.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %%
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used to visualize pairwise relationships among multiple numerical variables simultaneously. It helps identify correlations, distributions, clusters, and potential outliers in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Along with detailed analysis using bar graph and histogram,It also helps us to identify the outliers and exceptions which are present away from the general curve and points.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Optimize inventory to reduce out-of-stock products.
#
# Offer targeted discounts to increase sales while maintaining profits.
#
# Focus on high-demand product categories.
#
# Maintain competitive pricing strategies.
#
# Use data analytics for better inventory and pricing decisions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# This exploratory data analysis of the Zepto Inventory Dataset provided valuable insights into product categories, pricing, discounts, stock availability, and inventory distribution. The visualizations revealed important patterns that can help optimize inventory management, pricing strategies, and promotional activities. Overall, the analysis demonstrates how data-driven decision-making can improve customer satisfaction, operational efficiency, and business growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
